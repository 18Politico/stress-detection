# %%
# download preprocessed data and code from google drive
# !gdown 1BB4YGzMnowNG1E6bGAENGuJfTlnBpesn

# unzip it and remove the zip
# !unzip stress_detection.zip
# !rm stress_detection.zip

# %cd stress_detection/src/
# %run main_with_pickle.py
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BB4YGzMnowNG1E6bGAENGuJfTlnBpesn
# To: /content/stress_detection.zip
# 100% 2.34G/2.34G [00:28<00:00, 83.4MB/s]
# Archive:  stress_detection.zip
#    creating: stress_detection/dataset/
#   inflating: stress_detection/dataset/preprocessed_data.pkl
#    creating: stress_detection/dataset/WESAD/
#    creating: stress_detection/dataset/WESAD/S10/
#   inflating: stress_detection/dataset/WESAD/S10/S10.pkl
#  extracting: stress_detection/dataset/WESAD/S10/S10_E4_Data.zip
#   inflating: stress_detection/dataset/WESAD/S10/S10_quest.csv
#   inflating: stress_detection/dataset/WESAD/S10/S10_readme.txt
#   inflating: stress_detection/dataset/WESAD/S10/S10_respiban.txt
#    creating: stress_detection/dataset/WESAD/S11/
#   inflating: stress_detection/dataset/WESAD/S11/S11.pkl
#  extracting: stress_detection/dataset/WESAD/S11/S11_E4_Data.zip
#   inflating: stress_detection/dataset/WESAD/S11/S11_quest.csv
# ...
